# %%
import pandas as pd

# %%
daily = pd.read_csv(r'Apple-daily.csv')

# %%
x = daily[['Open','High','Low','Volume']]
y = daily[['Close','Adj Close']]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split( x , y , test_size = 0.2)

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
model = Lasso(alpha = 0.01)

# %%
model.fit(x_train , y_train)
# Out:
# C:\Users\ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.553e+02, tolerance: 1.880e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.019e+03, tolerance: 1.910e+02
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.01)

# %%
model.score(x_test , y_test)
# Out:
# 0.9989472931205248

# %%
from sklearn.metrics import r2_score
pred = model.predict(x_test)
r2_score(y_test , pred )
# Out:
# 0.9989472931205248

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error( y_test , pred )
# Out:
# 1.0476905961244063

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error( y_test , pred )
# Out:
# 2.025212844925991
