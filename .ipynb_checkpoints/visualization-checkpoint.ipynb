# %%
from pandas import read_csv as rc
from matplotlib import pyplot as plt

# %%
daily = rc(r'Apple-daily.csv')

# %%
daily.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2019-05-07  51.470001  51.855000  50.207500  50.715000  48.823273
# 1  2019-05-08  50.474998  51.334999  50.437500  50.724998  48.832893
# 2  2019-05-09  50.099998  50.419998  49.165001  50.180000  48.308228
# 3  2019-05-10  49.355000  49.712502  48.192501  49.294998  47.638996
# 4  2019-05-13  46.927502  47.369999  45.712502  46.430000  44.870247
#
#       Volume
# 0  155054800
# 1  105358000
# 2  139634400
# 3  164834800
# 4  229722400

# %%
'''plt.subplot(211)
plt.plot(daily['Date'] , daily ['Open'] , color = 'g' , label = 'open price')
plt.subplot(212)
plt.plot(daily['Date'] ,daily ['Close'] , color = 'r' , label = 'Close price')
plt.legend()
plt.show()'''
# Out:
# "plt.subplot(211)\nplt.plot(daily['Date'] , daily ['Open'] , color = 'g' , label = 'open price')\nplt.subplot(212)\nplt.plot(daily['Date'] ,daily ['Close'] , color = 'r' , label = 'Close price')\nplt.legend()\nplt.show()"

# %%
plt.plot(daily['Date'] , daily ['Open'] , color = 'g' , label = 'open price')

# %%
plt.plot(daily['Date'] ,daily ['Close'] , color = 'r' , label = 'Close price')

# %%
plt.plot(daily['Date'] ,daily ['Volume'] , color = 'b' , label = 'Volume')
